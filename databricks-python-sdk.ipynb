# %% [markdown]
# # Python SDK to create schema

# %%
from databricks.sdk import WorkspaceClient

client = WorkspaceClient()

client.schemas.create(catalog_name=catalog_name, name=schema_name)

# %% [markdown]
# # Python SDK to delete schema

# %%
from databricks.sdk import WorkspaceClient

client = WorkspaceClient()

client.schemas.delete(full_name="workspace.demo")

# %% [markdown]
# # List down jobs details

# %%
from databricks.sdk import WorkspaceClient

client = WorkspaceClient()

jobs = client.jobs.list()
for job in jobs:
    print(job)
# Out:
# BaseJob(created_time=1770442194826, creator_user_name='vargabghosh@gmail.com', effective_budget_policy_id='0b171420-6f45-4b7b-9247-c932c6710275', has_more=None, job_id=548935718407765, settings=JobSettings(budget_policy_id='0b171420-6f45-4b7b-9247-c932c6710275', continuous=None, deployment=JobDeployment(kind=<JobDeploymentKind.BUNDLE: 'BUNDLE'>, metadata_file_path='/Workspace/Users/vargabghosh@gmail.com/.bundle/my_project/dev/state/metadata.json'), description=None, edit_mode=<JobEditMode.UI_LOCKED: 'UI_LOCKED'>, email_notifications=JobEmailNotifications(no_alert_for_skipped_runs=None, on_duration_warning_threshold_exceeded=None, on_failure=['vargabghosh@gmail.com'], on_start=None, on_streaming_backlog_exceeded=None, on_success=None), environments=[], format=<Format.MULTI_TASK: 'MULTI_TASK'>, git_source=None, health=None, job_clusters=[], max_concurrent_runs=4, name='[dev vargabghosh] my_project_job', notification_settings=None, parameters=[], performance_target=None, queue=QueueSettings(enabled=True), run_as=None, schedule=None, tags={'dev': 'vargabghosh'}, tasks=[], timeout_seconds=0, trigger=TriggerSettings(file_arrival=None, pause_status=<PauseStatus.PAUSED: 'PAUSED'>, periodic=PeriodicTriggerConfiguration(interval=1, unit=<PeriodicTriggerConfigurationTimeUnit.DAYS: 'DAYS'>), table=None, table_update=None), webhook_notifications=None))
# BaseJob(created_time=1770287291981, creator_user_name='vargabghosh@gmail.com', effective_budget_policy_id='0b171420-6f45-4b7b-9247-c932c6710275', has_more=None, job_id=49004023938539, settings=JobSettings(budget_policy_id=None, continuous=None, deployment=None, description=None, edit_mode=None, email_notifications=JobEmailNotifications(no_alert_for_skipped_runs=False, on_duration_warning_threshold_exceeded=None, on_failure=None, on_start=None, on_streaming_backlog_exceeded=None, on_success=None), environments=[], format=<Format.MULTI_TASK: 'MULTI_TASK'>, git_source=None, health=None, job_clusters=[], max_concurrent_runs=1, name='schema-create', notification_settings=None, parameters=[], performance_target=<PerformanceTarget.PERFORMANCE_OPTIMIZED: 'PERFORMANCE_OPTIMIZED'>, queue=QueueSettings(enabled=True), run_as=None, schedule=None, tags=None, tasks=[], timeout_seconds=0, trigger=None, webhook_notifications=None))
