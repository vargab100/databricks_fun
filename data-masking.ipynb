# %% [markdown]
# # **Create a UDF - Masking**

# %%
# %sql
CREATE OR REPLACE FUNCTION workspace.my_project_dev.mask_if_not_test_group(val STRING) ---replace with your own location
RETURN
  CASE
    WHEN is_member('test-group') THEN val ---replace with your own group display name
    ELSE '****'
  END;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# # **Apply masking on specefic**

# %%
# %sql
ALTER TABLE workspace.my_project_dev.filtered_taxis_demo ---replace with your own table location
ALTER COLUMN dropoff_zip ---replace with your table column name
SET MASK workspace.my_project_dev.mask_if_not_test_group; ---replace with your own function

# %% [markdown]
# # **Remove the masking**

# %%
# %sql
ALTER TABLE workspace.my_project_dev.filtered_taxis_demo ---replace with your own table location
ALTER COLUMN dropoff_zip ---replace with your table column name
DROP MASK;
