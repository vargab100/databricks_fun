# %% [markdown]
# # Agent Creation with LangChain Tool Integration -
# # (wikipedia,duckduckgo-search,youtube-tool-search,ChatDatabricks)

# %%
pip install -qU langchain-community wikipedia
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from langchain_community.retrievers import WikipediaRetriever

retriever = WikipediaRetriever()

# %%
docs = retriever.invoke("TOKYO GHOUL")

# %%
print(docs[0].page_content[:400])
# Out:
# Tokyo Ghoul (Japanese: 東京喰種（トーキョーグール）, Hepburn: Tōkyō Gūru) is a Japanese dark fantasy manga series written and illustrated by Sui Ishida. It was serialized in Shueisha's seinen manga magazine Weekly Young Jump from September 2011 to September 2014, with its chapters collected in 14 tankōbon volumes. The manga has been licensed for English release in North America by Viz Media.
# The story is set in

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# Configure the wrapper (optional, defaults are fine for a start)
api_wrapper = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=200)

# Initialize the tool
wikipedia_tool = WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
result = wikipedia_tool.invoke("What is GenAI")
print(result)
# Out:
# Page: Generative artificial intelligence
# Summary: Generative artificial intelligence, also known as generative AI or GenAI, is a subfield of artificial intelligence that uses generative models to gene

# %%
result2 = wikipedia_tool.run("What is GenAI")
print(result2)
# Out:
# Page: Generative artificial intelligence
# Summary: Generative artificial intelligence, also known as generative AI or GenAI, is a subfield of artificial intelligence that uses generative models to gene

# %%
pip install duckduckgo-search
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 93.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 97.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Not uninstalling click at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-48fc2401-f620-4136-b9da-3bd39c98f11a
#     Can't uninstall 'click'. No files were found to uninstall.
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_community.tools import DuckDuckGoSearchResults

# %%
pip install -U ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 37.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Not uninstalling httpx at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-48fc2401-f620-4136-b9da-3bd39c98f11a
#     Can't uninstall 'httpx'. No files were found to uninstall.
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# Initialize the search tool
search = DuckDuckGoSearchRun()

# %%
search.run("What is GenAI")
# Out:
# "3 days ago · Generative artificial intelligence, also known as generative AI or GenAI, is a subfield of artificial intelligence that uses generative models to generate text ... May 6, 2025 · Welcome to Day 1 of our 30 Days of GenAI learning challenge! Today you'll create your first AI chat - no experience needed. Join thousands learning AI in ... Sep 22, 2025 · GenAI, short for Generative Artificial Intelligence, refers to AI systems capable of generating new content, ideas, or data that mimic human-like ... Oct 17, 2025 · In simpler terms, Generative AI (GenAI) is a type of artificial intelligence technology that can produce various types of content using Large Language Models ( ... Aug 15, 2025 · GenAI is a type of machine learning focused on building generative models capable of producing a wide range of AI-generated content, including human-like text, ..."

# %%
from langchain_community.document_loaders import YoutubeLoader
from langchain_community.document_loaders import GoogleApiYoutubeLoader

# %%
pip install youtube_search
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from langchain_community.tools import YouTubeSearchTool
youtube_tool = YouTubeSearchTool()
youtube_tool.run("GenAI")
# Out:
# "['https://www.youtube.com/watch?v=NRmAXDWJVnU&pp=ygUFR2VuQUk%3D', 'https://www.youtube.com/watch?v=EDb37y_MhRw&pp=ygUFR2VuQUk%3D']"

# %%
# %pip install --upgrade databricks-langchain langchain-community langchain databricks-sql-connector
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.6 MB/s eta 0:00:00
# ...
#   Created wheel for thrift: filename=thrift-0.20.0-cp312-cp312-linux_aarch64.whl size=409741 sha256=1dca85cffdb2b76c46827085d4682a03e66d99986d3126517dc5431408437e6e
#   Stored in directory: /home/spark-48fc2401-f620-4136-b9da-3b/.cache/pip/wheels/57/4d/9e/539ef8e052f8e2db244ddf8ac1f2e623b4663f2ee233ffafb1
# Successfully built thrift
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
pip install -qU databricks-langchain
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
 # %restart_python

# %%
from databricks_langchain import ChatDatabricks

chat_model = ChatDatabricks(
    endpoint="databricks-meta-llama-3-3-70b-instruct",
    temperature=0.1,
    max_tokens=256,
    # See https://python.langchain.com/api_reference/community/chat_models/langchain_community.chat_models.databricks.ChatDatabricks.html for other supported parameters
)

# %%
chat_model.invoke("What is MLflow?")
# Out:
# AIMessage(content='**MLflow** is an open-source platform for managing the end-to-end machine learning (ML) lifecycle. It was developed by Databricks and is designed to help data scientists and engineers streamline their ML workflows, from data preparation to model deployment.\n\n### Key Features of MLflow\n\n1. **Model Management**: MLflow provides a centralized model registry for storing, versioning, and managing ML models.\n2. **Experiment Tracking**: MLflow allows users to track and log experiments, including hyperparameters, metrics, and artifacts.\n3. **Model Serving**: MLflow provides a simple way to deploy and serve ML models in various environments, such as cloud, on-premises, or edge devices.\n4. **Reproducibility**: MLflow enables reproducibility by storing and managing the entire ML workflow, including data, code, and environment.\n\n### Components of MLflow\n\n1. **MLflow Tracking**: Tracks and logs experiments, including hyperparameters, metrics, and artifacts.\n2. **MLf
# ...
